# %% [markdown]
# <h1>GLOBAL TERRORIST DATA REPORT ANALYSIS</h1>
#
# <H4>Analyst: Abdul Barry A. Adam</H4>

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import folium

import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Getting the local datasets

# %%
global_terrorist = pd.read_csv('./datasets/Global_terrorist.csv', encoding='ISO-8859-1')

# %%
global_terrorist.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
global_terrorist
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
southEast_Asia = global_terrorist[global_terrorist["region_txt"] == 'Southeast Asia']

# %%
PH = global_terrorist[global_terrorist["country_txt"] == 'Philippines']

# %%
PH
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 2       197001000001   1970       1     0        NaN         0        NaN
# 26      197001210001   1970       1    21        NaN         0        NaN
# 39      197001310001   1970       1    31        NaN         0        NaN
# 96      197003000001   1970       3     0        NaN         0        NaN
# 150     197003240001   1970       3    24        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181677  201712310010   2017      12    31        NaN         0        NaN
# 181678  201712310011   2017      12    30        NaN         0        NaN
# 181681  201712310016   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ...  \
# ...

# %%
import folium
from folium.plugins import HeatMap

# step 1: Prepare the data
heat_data = []
